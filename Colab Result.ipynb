# %% [markdown]
# Colab result: L4 GPU
#
# train_data = 10528
# val_data = 3506
# test_data = 3000
# Input shape = (150,150,3)
#
# Pre-training: imagenet, global pooling = ‘max’
# Layers: dropout(0.4) > batchnorm > dense (256, relu)> dense(256,relu)>dropout(0.5)>dense(6,softmax)
# Optimizer: adamax(learningrate=0.0001) #beta_1=0.9, beta_2=0.999
#
# Total params: 6,975,629 (26.61 MB)
# Trainable params: 6,911,014 (26.36 MB)
# Non-trainable params: 64,615 (252.41 KB)
#
# Training time: 97min for epochs 25
# Training accuracy=0.9587, loss=0.1157
# Validation accuracy=0.9256, loss=0.2294
# Test accuracy=0.9155,loss=0.2550
#
# ![image.png](attachment:image.png)
# ![image2.png](attachment:image-2.png)
#
# {'buildings': 0, 'forest': 1, 'glacier': 2,'mountain': 3, 'sea': 4, 'street': 5}
#                  precision   recall  f1-score   support
#            0       0.94      0.90    0.92       437
#            1       0.99      0.99    0.99       474
#            2       0.90      0.84    0.87       553
#            3       0.87      0.89    0.88       525
#            4       0.95      0.97    0.96       510
#            5       0.91      0.96    0.93       501
#     accuracy                         0.92      3000
#    macro avg       0.93      0.92    0.92      3000
# weighted avg       0.92      0.92    0.92      3000
#
# Precision: % of positive predictions that were correct = TP/(TP+FP). High: Few false positives
# Recall: % of actual positives correctly identified = TP/(TP+FN). High: Few false negatives
# F1-score: Harmonic mean of precision and recall = 2*(Precision*Recall)/(Precision+Recall)
# Support: Number of samples for each class
#
# Comment:
# 1)	High precision and recall (>0.8) for all classes
# 2)	Small differences between macro/weighted avg
# 3)	Similar support numbers
#
# ![image-3.png](attachment:image-3.png)
# Comment: high confusion between class 'glacier': 2,'mountain': 3
